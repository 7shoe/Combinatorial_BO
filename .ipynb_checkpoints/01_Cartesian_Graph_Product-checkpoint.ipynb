# %%
import os
import networkx as nx
from matplotlib import pyplot as plt
import numpy as np
from matplotlib.colors import LinearSegmentedColormap

# %%
G = nx.Graph()
H = nx.Graph()
G.add_node(0, a1=True)
H.add_node("a", a2="Spam")
P = nx.cartesian_product(G, H)
list(P)
[(0, 'a')]
# Out:
# [(0, 'a')]

# %%
# Graph of 
G = nx.Graph()

# - E: edge set
G.add_edge(32, 64)
G.add_edge(64, 128)

plt.figure(figsize=(6,5))
nx.draw(G, pos = {32 : (-5,5), 64 : (-5,10), 128 : (-5,15)}, 
        with_labels=True, node_size=1500, node_color='#6495ED', node_shape='o', alpha=0.9,
       edge_color='grey', font_size=20, font_family='Arial')

# %%
# (2.) Optimizer
H = nx.Graph()

# - E: edge set
H.add_edge('SGD', 'Adam')
H.add_edge('Adam', 'RMS')
H.add_edge('RMS', 'SGD')

plt.figure(figsize=(6,5))
nx.draw(H, pos = {'SGD' : (0,5), 'Adam' : (5,2.5), 'RMS' : (-5, 2.5)}, font_color='white', 
        with_labels=True, node_size=3500, node_color='#D22B2B', node_shape='o', alpha=0.98,
       edge_color='grey', font_size=17, font_family='Arial')

# %%
P1 = nx.cartesian_product(G, H)

plt.figure(figsize=(7,6))
nx.draw(P1, font_color='white', 
        with_labels=True, node_size=5500, node_shape='o', alpha=0.98, 
       edge_color='grey', font_size=12, font_family='Arial')

# %%
#karate_agr = nx.nx_agraph.to_agraph(karate)

P1.nodes['style'] = 'filled'
P1.node_attr['shape'] = 'circle'
P1.node_attr['gradientangle'] = 90


color_map = []
for nodeLoc in P1.nodes():
    print(nodeLoc)
    n = P1.nodes(nodeLoc)
    #print(n)
    color_map.append('#D22B2B;0.5:#6495ED')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [234], in <cell line: 3>()
#       1 #karate_agr = nx.nx_agraph.to_agraph(karate)
# ----> 3 P1.nodes['style'] = 'filled'
#       4 P1.node_attr['shape'] = 'circle'
#       5 P1.node_attr['gradientangle'] = 90
#
# TypeError: 'NodeView' object does not support item assignment

# %%
# (3.) Optimizer
I = nx.Graph()

# - E: edge set
I.add_edge('$10^{-2}$', '$10^{-3}$')
I.add_edge('$10^{-3}$', '$10^{-4}$')

plt.figure(figsize=(6,5))
nx.draw(I, pos = {'$10^{-2}$' : (0,5), '$10^{-3}$' : (0,10), '$10^{-4}$' : (0,15)}, font_color='white', 
        with_labels=True, node_size=3500, node_color='#3EB489', node_shape='o', alpha=0.98,
       edge_color='grey', font_size=17, font_family='Arial')

# %%
P2 = nx.cartesian_product(P1, H)

plt.figure(figsize=(12, 8))
nx.draw(P2, font_color='white', 
        with_labels=False, node_size=1500, node_color='#533440', node_shape='o', alpha=0.98,
       edge_color='grey', font_size=9, font_family='Arial')

# %%
# (4.) Architecture: Hidden Layers
I = nx.Graph()

# - E: edge set
I.add_edge('[32, 64]', '[32, 64, 128]')
I.add_edge('[32, 64, 128]', '[32, 64, \n   128, 256]')

plt.figure(figsize=(5,8))
nx.draw(I, pos = {'[32, 64]' : (0,0), '[32, 64, 128]' : (0,4), '[32, 64, \n   128, 256]' : (0,8)}, font_color='black', 
        with_labels=True, node_size=7000, node_color='#FF8B13', node_shape='o', alpha=0.98,
       edge_color='grey', font_size=14, font_family='Arial')

# %%
# (6.) Architecture: Hidden Layers
J = nx.complete_graph(['ReLU', '$tanh$', 'Leaky\nReLU', 'Sigmoid'])

plt.figure(figsize=(5,5))
nx.draw(J, font_color='black', 
        with_labels=True, node_size=2000, node_color='#FF5F7E', node_shape='o', alpha=0.98,
       edge_color='grey', font_size=12, font_family='Arial')

# %%
P3 = nx.cartesian_product(P2, I)
P4 = nx.cartesian_product(P3, J)

plt.figure(figsize=(12, 8))
nx.draw(P4, font_color='white', 
        with_labels=False, node_size=90, node_color='#533440', node_shape='o', alpha=0.98,
       edge_color='lightgrey', font_size=9, font_family='Arial')

# %% [markdown]
# ## Test: Every Node is a Pie Chart

# %%
# parameters for pie plot
radius = 0.2
cmap = plt.cm.viridis

# make graph
G = nx.Graph()
nodes = [1,2,3,4]
edges = ((1,2),(3,2),(1,4),(3,4))
G.add_nodes_from(nodes)
G.add_edges_from(edges)
pos = nx.spring_layout(G)


# storing attributes in a dict
attrs = {
    1:[1,1,1],
    2:[0.5, 1, 0],
    3:[0, 0.6, 0],
    4:[0.5, 1, 0.5],
}

# normalising data to make colors
a = np.array(list(attrs.values()))
maxes = np.max(a, axis=0) # note that this will throw an error if different nodes have different number of features. 


# collect colors in dictionary    
colors= {}

for key, val in attrs.items():
    colors[key] = list(np.array(val)/maxes)

# draw graph and draw pieplots instead of nodes

nx.draw_networkx_edges(G, pos=pos)
for node in G.nodes:

    attributes = attrs[node]

    a = plt.pie(
        [1]*len(attributes), # s.t. all wedges have equal size
        center=pos[node], 
        colors = [cmap(a) for a in colors[node]],
        radius=radius)

plt.ylim(-2,2)
plt.xlim(-2,2)
# Out:
# (-2.0, 2.0)

# %%
N = 9 # number of graphs in box product
pos = nx.spring_layout(P1)

attrs = {nodeVal:[0.5, -0.5] for nodeVal in P1.nodes()}
colors= {}

plt.figure(figsize=(10,8))
for key, val in attrs.items():
    colors[key] = list(np.array(val))
    
# positions
txtList   = []
coordList = []

for k, v in pos.items():
    print(k, v)
    txtList.append(str(k).replace("\'", ""))
    coordList.append(v)

# draw edges
nx.draw_networkx_edges(P1, pos=pos)

# color nodes
for node in P1.nodes():
    attributes = attrs[node]
    # pie
    a = plt.pie(
        [1]*len(attributes), # s.t. all wedges have equal size
        center=pos[node], 
        colors = [cmap(a) for a in colors[node]],
        radius=radius)

plt.ylim(-1,1)
plt.xlim(-1,1)

for i in range(len(coordList)):
    plt.text(s=txtList[i],x=coordList[i][0]-0.1,y=coordList[i][1]+0.025, c='white')
# Out:
# (32, 'SGD') [0.91007046 0.29651999]
# (32, 'Adam') [ 0.60757585 -0.0298372 ]
# (32, 'RMS') [ 0.88596167 -0.36777301]
# (64, 'SGD') [0.10535499 0.35157452]
# (64, 'Adam') [-0.18920025 -0.00286804]
# (64, 'RMS') [ 0.07483079 -0.37781142]
# (128, 'SGD') [-0.68112311  0.39134239]
# (128, 'Adam') [-1.          0.05190725]
# (128, 'RMS') [-0.71347038 -0.31305448]

# %%
P2.nodes
# Out:
# NodeView((((32, 'SGD'), 'SGD'), ((32, 'SGD'), 'Adam'), ((32, 'SGD'), 'RMS'), ((32, 'Adam'), 'SGD'), ((32, 'Adam'), 'Adam'), ((32, 'Adam'), 'RMS'), ((32, 'RMS'), 'SGD'), ((32, 'RMS'), 'Adam'), ((32, 'RMS'), 'RMS'), ((64, 'SGD'), 'SGD'), ((64, 'SGD'), 'Adam'), ((64, 'SGD'), 'RMS'), ((64, 'Adam'), 'SGD'), ((64, 'Adam'), 'Adam'), ((64, 'Adam'), 'RMS'), ((64, 'RMS'), 'SGD'), ((64, 'RMS'), 'Adam'), ((64, 'RMS'), 'RMS'), ((128, 'SGD'), 'SGD'), ((128, 'SGD'), 'Adam'), ((128, 'SGD'), 'RMS'), ((128, 'Adam'), 'SGD'), ((128, 'Adam'), 'Adam'), ((128, 'Adam'), 'RMS'), ((128, 'RMS'), 'SGD'), ((128, 'RMS'), 'Adam'), ((128, 'RMS'), 'RMS')))

# %%
P1 = nx.cartesian_product(G, H)
P2 = nx.cartesian_product(P1, I)

cmap = LinearSegmentedColormap.from_list('newCmap', ['#6495ED', '#D22B2B', '#3EB489'])

pos = nx.spring_layout(P2)

attrs = {nodeVal:[0, 0.5, 1.0] for nodeVal in P2.nodes()}
colors= {}

plt.figure(figsize=(12,12))
for key, val in attrs.items():
    colors[key] = list(np.array(val))
    
# positions
txtList   = []
coordList = []

for k, v in pos.items():
    print(k, v)
    txtList.append(str(k).replace("\'", ""))
    coordList.append(v)

# draw edges
nx.draw_networkx_edges(P2, pos=pos)

# color nodes
for node in P2.nodes():
    attributes = attrs[node]
    # pie
    a = plt.pie(
        [1]*len(attributes), # s.t. all wedges have equal size
        center=pos[node], 
        colors = [cmap(a) for a in colors[node]],
        radius=0.1)

plt.ylim(-1,1)
plt.xlim(-1,1)


# text formatting
newTxtList = []
for i in range(len(txtList)): 
    newT = [patt.replace('$10^{', '').replace('}$', '') if '$' in patt else patt for patt in txtList[i].replace(')', '').replace('(', '').split(', ')]
    newTxtList.append(r', '.join(newT[:-1] + [r'$10^{' + str(newT[-1]) + '}$']))

for i in range(len(newTxtList)):
    plt.text(s=newTxtList[i].replace('SGD,', 'SGD,\n').replace('Adam,', 'Adam,\n').replace('RMS,', 'RMS,\n'), 
             x=coordList[i][0]-0.07,
             y=coordList[i][1]-0.025, 
             c='white', 
             fontsize=10)

plt.show()
# Out:
# ((32, 'SGD'), '$10^{-2}$') [-0.14137752  0.68766616]
# ((32, 'SGD'), '$10^{-3}$') [0.42869576 0.44504214]
# ((32, 'SGD'), '$10^{-4}$') [0.9848128  0.16152749]
# ((32, 'Adam'), '$10^{-2}$') [-0.44038717  0.7458617 ]
# ((32, 'Adam'), '$10^{-3}$') [0.14227198 0.50316651]
# ((32, 'Adam'), '$10^{-4}$') [0.70635515 0.23012647]
# ((32, 'RMS'), '$10^{-2}$') [-0.23706443  0.96620955]
# ((32, 'RMS'), '$10^{-3}$') [0.32243095 0.74274112]
# ((32, 'RMS'), '$10^{-4}$') [0.8641033  0.48041791]
# ((64, 'SGD'), '$10^{-2}$') [-0.44521955  0.145391  ]
# ((64, 'SGD'), '$10^{-3}$') [ 0.13628061 -0.11651662]
# ((64, 'SGD'), '$10^{-4}$') [ 0.71865051 -0.37042927]
# ((64, 'Adam'), '$10^{-2}$') [-0.73765859  0.21162336]
# ((64, 'Adam'), '$10^{-3}$') [-0.15573462 -0.06056472]
# ((64, 'Adam'), '$10^{-4}$') [ 0.42691867 -0.32521397]
# ((64, 'RMS'), '$10^{-2}$') [-0.55720527  0.43053766]
# ((64, 'RMS'), '$10^{-3}$') [0.02179218 0.17894778]
# ((64, 'RMS'), '$10^{-4}$') [ 0.59438302 -0.0802784 ]
# ((128, 'SGD'), '$10^{-2}$') [-0.71961758 -0.41240055]
# ((128, 'SGD'), '$10^{-3}$') [-0.16963898 -0.66926593]
# ((128, 'SGD'), '$10^{-4}$') [ 0.41194713 -0.8935629 ]
# ((128, 'Adam'), '$10^{-2}$') [-1.         -0.35126685]
# ((128, 'Adam'), '$10^{-3}$') [-0.45315435 -0.63918291]
# ((128, 'Adam'), '$10^{-4}$') [ 0.11164075 -0.87489847]
# ((128, 'RMS'), '$10^{-2}$') [-0.83394491 -0.11850351]
# ((128, 'RMS'), '$10^{-3}$') [-0.27503893 -0.39107057]
# ((128, 'RMS'), '$10^{-4}$') [ 0.29575909 -0.62610419]

# %%
P1 = nx.cartesian_product(G, H)
P2 = nx.cartesian_product(P1, I)
J = nx.complete_graph(['ReLU', '$tanh$', 'Leaky\nReLU', 'Sigmoid'])

P3 = nx.cartesian_product(P2, J)

cmap = LinearSegmentedColormap.from_list('newCmap', ['#6495ED', '#D22B2B', '#3EB489', '#FF5F7E', '#FF8B13'])

pos = nx.spring_layout(P3)

attrs = {nodeVal:[0, 0.25, 0.75, 1.0] for nodeVal in P3.nodes()}
colors= {}

plt.figure(figsize=(12,12))
for key, val in attrs.items():
    colors[key] = list(np.array(val))
    
# positions
txtList   = []
coordList = []

for k, v in pos.items():
    print(k, v)
    txtList.append(str(k).replace("\'", ""))
    coordList.append(v)

# draw edges
nx.draw_networkx_edges(P3, pos=pos)

# color nodes
for node in P3.nodes():
    attributes = attrs[node]
    # pie
    a = plt.pie(
        [1]*len(attributes), # s.t. all wedges have equal size
        center=pos[node], 
        colors = [cmap(a) for a in colors[node]],
        radius=0.045)

plt.ylim(-1,1)
plt.xlim(-1,1)


# text formatting
newTxtList = []
for i in range(len(txtList)): 
    newT = [patt.replace('$10^{', '').replace('}$', '') if '$' in patt else patt for patt in txtList[i].replace(')', '').replace('(', '').split(', ')]
    newTxtList.append(r', '.join(newT[:-2] + [r'$10^{' + str(newT[-2]) + '}$'] + [newT[-1]]))

#for i in range(len(newTxtList)):
#    plt.text(s=newTxtList[i].replace('SGD,', 'SGD,\n').replace('Adam,', 'Adam,\n').replace('RMS,', 'RMS,\n'), 
#             x=coordList[i][0]-0.07,
#             y=coordList[i][1]-0.025, 
#             c='white', 
#             fontsize=3)

plt.show()
# Out:
# (((32, 'SGD'), '$10^{-2}$'), 'ReLU') [-0.55762013 -0.31487519]
# (((32, 'SGD'), '$10^{-2}$'), '$tanh$') [-0.48625107 -0.10989449]
# (((32, 'SGD'), '$10^{-2}$'), 'Leaky\nReLU') [-0.67136806 -0.23104522]
# (((32, 'SGD'), '$10^{-2}$'), 'Sigmoid') [-0.5896241  -0.09726514]
# (((32, 'SGD'), '$10^{-3}$'), 'ReLU') [-0.09949018 -0.65978873]
# (((32, 'SGD'), '$10^{-3}$'), '$tanh$') [-0.02244501 -0.45508369]
# (((32, 'SGD'), '$10^{-3}$'), 'Leaky\nReLU') [-0.23503368 -0.58934796]
# (((32, 'SGD'), '$10^{-3}$'), 'Sigmoid') [-0.13736811 -0.46827147]
# (((32, 'SGD'), '$10^{-4}$'), 'ReLU') [ 0.39373505 -0.97876122]
# (((32, 'SGD'), '$10^{-4}$'), '$tanh$') [ 0.46515997 -0.79214405]
# (((32, 'SGD'), '$10^{-4}$'), 'Leaky\nReLU') [ 0.21081035 -0.9533387 ]
# (((32, 'SGD'), '$10^{-4}$'), 'Sigmoid') [ 0.34230263 -0.80416071]
# (((32, 'Adam'), '$10^{-2}$'), 'ReLU') [-0.86137198 -0.33360044]
# (((32, 'Adam'), '$10^{-2}$'), '$tanh$') [-0.82855545 -0.07594039]
# (((32, 'Adam'), '$10^{-2}$'), 'Leaky\nReLU') [-0.99252728 -0.23693184]
# (((32, 'Adam'), '$10^{-2}$'), 'Sigmoid') [-0.93682996 -0.07280924]
# (((32, 'Adam'), '$10^{-3}$'), 'ReLU') [-0.41454492 -0.68060957]
# (((32, 'Adam'), '$10^{-3}$'), '$tanh$') [-0.36611326 -0.4355847 ]
# (((32, 'Adam'), '$10^{-3}$'), 'Leaky\nReLU') [-0.5617011  -0.60334567]
# (((32, 'Adam'), '$10^{-3}$'), 'Sigmoid') [-0.49059003 -0.46291843]
# (((32, 'Adam'), '$10^{-4}$'), 'ReLU') [ 0.05916929 -0.99453435]
# (((32, 'Adam'), '$10^{-4}$'), '$tanh$') [ 0.11680786 -0.75922245]
# (((32, 'Adam'), '$10^{-4}$'), 'Leaky\nReLU') [-0.10667016 -0.92858476]
# (((32, 'Adam'), '$10^{-4}$'), 'Sigmoid') [-0.01264124 -0.78469238]
# (((32, 'RMS'), '$10^{-2}$'), 'ReLU') [-0.70908944 -0.30773129]
# (((32, 'RMS'), '$10^{-2}$'), '$tanh$') [-0.65619235 -0.0290363 ]
# (((32, 'RMS'), '$10^{-2}$'), 'Leaky\nReLU') [-0.8336102  -0.19314483]
# (((32, 'RMS'), '$10^{-2}$'), 'Sigmoid') [-0.76208651 -0.0080574 ]
# (((32, 'RMS'), '$10^{-3}$'), 'ReLU') [-0.23975304 -0.64804803]
# (((32, 'RMS'), '$10^{-3}$'), '$tanh$') [-0.17386349 -0.37051022]
# (((32, 'RMS'), '$10^{-3}$'), 'Leaky\nReLU') [-0.38810752 -0.54870535]
# (((32, 'RMS'), '$10^{-3}$'), 'Sigmoid') [-0.29239411 -0.36179792]
# (((32, 'RMS'), '$10^{-4}$'), 'ReLU') [ 0.27546376 -0.90596431]
# (((32, 'RMS'), '$10^{-4}$'), '$tanh$') [ 0.31775184 -0.68527995]
# (((32, 'RMS'), '$10^{-4}$'), 'Leaky\nReLU') [ 0.08559018 -0.85775146]
# (((32, 'RMS'), '$10^{-4}$'), 'Sigmoid') [ 0.19205848 -0.68077321]
# (((64, 'SGD'), '$10^{-2}$'), 'ReLU') [-0.28137759  0.20923841]
# (((64, 'SGD'), '$10^{-2}$'), '$tanh$') [-0.20492282  0.40519005]
# (((64, 'SGD'), '$10^{-2}$'), 'Leaky\nReLU') [-0.4183509   0.28607948]
# (((64, 'SGD'), '$10^{-2}$'), 'Sigmoid') [-0.33014829  0.41042638]
# (((64, 'SGD'), '$10^{-3}$'), 'ReLU') [ 0.19211932 -0.14422168]
# (((64, 'SGD'), '$10^{-3}$'), '$tanh$') [0.25918034 0.04588311]
# (((64, 'SGD'), '$10^{-3}$'), 'Leaky\nReLU') [ 0.03422959 -0.08020793]
# (((64, 'SGD'), '$10^{-3}$'), 'Sigmoid') [0.13911602 0.04949076]
# (((64, 'SGD'), '$10^{-4}$'), 'ReLU') [ 0.68075123 -0.50487737]
# (((64, 'SGD'), '$10^{-4}$'), '$tanh$') [ 0.74027101 -0.30814977]
# (((64, 'SGD'), '$10^{-4}$'), 'Leaky\nReLU') [ 0.51001541 -0.47533111]
# (((64, 'SGD'), '$10^{-4}$'), 'Sigmoid') [ 0.61978869 -0.30207572]
# (((64, 'Adam'), '$10^{-2}$'), 'ReLU') [-0.60769438  0.1989503 ]
# (((64, 'Adam'), '$10^{-2}$'), '$tanh$') [-0.56804589  0.43146099]
# (((64, 'Adam'), '$10^{-2}$'), 'Leaky\nReLU') [-0.75343059  0.28252374]
# (((64, 'Adam'), '$10^{-2}$'), 'Sigmoid') [-0.68927659  0.43593176]
# (((64, 'Adam'), '$10^{-3}$'), 'ReLU') [-0.13221516 -0.15475615]
# (((64, 'Adam'), '$10^{-3}$'), '$tanh$') [-0.07716551  0.08509202]
# (((64, 'Adam'), '$10^{-3}$'), 'Leaky\nReLU') [-0.28413891 -0.08326633]
# (((64, 'Adam'), '$10^{-3}$'), 'Sigmoid') [-0.20774917  0.06741842]
# (((64, 'Adam'), '$10^{-4}$'), 'ReLU') [ 0.35501961 -0.48970503]
# (((64, 'Adam'), '$10^{-4}$'), '$tanh$') [ 0.40758003 -0.26562262]
# (((64, 'Adam'), '$10^{-4}$'), 'Leaky\nReLU') [ 0.19563072 -0.42244335]
# (((64, 'Adam'), '$10^{-4}$'), 'Sigmoid') [ 0.2758003  -0.27620213]
# (((64, 'RMS'), '$10^{-2}$'), 'ReLU') [-0.4483117  0.2181042]
# (((64, 'RMS'), '$10^{-2}$'), '$tanh$') [-0.38379353  0.48454161]
# (((64, 'RMS'), '$10^{-2}$'), 'Leaky\nReLU') [-0.58801225  0.32182928]
# (((64, 'RMS'), '$10^{-2}$'), 'Sigmoid') [-0.50125686  0.50524676]
# (((64, 'RMS'), '$10^{-3}$'), 'ReLU') [ 0.05296653 -0.11461818]
# (((64, 'RMS'), '$10^{-3}$'), '$tanh$') [0.10673809 0.15267092]
# (((64, 'RMS'), '$10^{-3}$'), 'Leaky\nReLU') [-0.10695668 -0.02009632]
# (((64, 'RMS'), '$10^{-3}$'), 'Sigmoid') [-0.01441846  0.16373098]
# (((64, 'RMS'), '$10^{-4}$'), 'ReLU') [ 0.55165234 -0.39741563]
# (((64, 'RMS'), '$10^{-4}$'), '$tanh$') [ 0.59799582 -0.18373191]
# (((64, 'RMS'), '$10^{-4}$'), 'Leaky\nReLU') [ 0.3748388 -0.3636261]
# (((64, 'RMS'), '$10^{-4}$'), 'Sigmoid') [ 0.47050145 -0.16811284]
# (((128, 'SGD'), '$10^{-2}$'), 'ReLU') [0.00576898 0.72893428]
# (((128, 'SGD'), '$10^{-2}$'), '$tanh$') [0.09329142 0.90332473]
# (((128, 'SGD'), '$10^{-2}$'), 'Leaky\nReLU') [-0.11670527  0.76926499]
# (((128, 'SGD'), '$10^{-2}$'), 'Sigmoid') [-0.03555712  0.90864713]
# (((128, 'SGD'), '$10^{-3}$'), 'ReLU') [0.46935864 0.38469739]
# (((128, 'SGD'), '$10^{-3}$'), '$tanh$') [0.55058642 0.56593415]
# (((128, 'SGD'), '$10^{-3}$'), 'Leaky\nReLU') [0.32767816 0.38949349]
# (((128, 'SGD'), '$10^{-3}$'), 'Sigmoid') [0.42002872 0.57829992]
# (((128, 'SGD'), '$10^{-4}$'), 'ReLU') [0.92563131 0.00161737]
# (((128, 'SGD'), '$10^{-4}$'), '$tanh$') [0.98058655 0.19250487]
# (((128, 'SGD'), '$10^{-4}$'), 'Leaky\nReLU') [0.78616918 0.01158389]
# (((128, 'SGD'), '$10^{-4}$'), 'Sigmoid') [0.86405878 0.21397791]
# (((128, 'Adam'), '$10^{-2}$'), 'ReLU') [-0.33438103  0.69648786]
# (((128, 'Adam'), '$10^{-2}$'), '$tanh$') [-0.25995332  0.91394802]
# (((128, 'Adam'), '$10^{-2}$'), 'Leaky\nReLU') [-0.47736095  0.76720922]
# (((128, 'Adam'), '$10^{-2}$'), 'Sigmoid') [-0.3992431  0.9207731]
# (((128, 'Adam'), '$10^{-3}$'), 'ReLU') [0.15169187 0.36891264]
# (((128, 'Adam'), '$10^{-3}$'), '$tanh$') [0.21877201 0.59210551]
# (((128, 'Adam'), '$10^{-3}$'), 'Leaky\nReLU') [0.00622133 0.43229068]
# (((128, 'Adam'), '$10^{-3}$'), 'Sigmoid') [0.0803036  0.58882866]
# (((128, 'Adam'), '$10^{-4}$'), 'ReLU') [0.62207686 0.02095934]
# (((128, 'Adam'), '$10^{-4}$'), '$tanh$') [0.67755149 0.25442209]
# (((128, 'Adam'), '$10^{-4}$'), 'Leaky\nReLU') [0.47684806 0.08421435]
# (((128, 'Adam'), '$10^{-4}$'), 'Sigmoid') [0.54771544 0.24995373]
# (((128, 'RMS'), '$10^{-2}$'), 'ReLU') [-0.17223113  0.73620798]
# (((128, 'RMS'), '$10^{-2}$'), '$tanh$') [-0.08430352  0.98281923]
# (((128, 'RMS'), '$10^{-2}$'), 'Leaky\nReLU') [-0.30342207  0.81830118]
# (((128, 'RMS'), '$10^{-2}$'), 'Sigmoid') [-0.21128225  1.        ]
# (((128, 'RMS'), '$10^{-3}$'), 'ReLU') [0.32454435 0.46019556]
# (((128, 'RMS'), '$10^{-3}$'), '$tanh$') [0.3979951  0.68466553]
# (((128, 'RMS'), '$10^{-3}$'), 'Leaky\nReLU') [0.1800775  0.49495287]
# (((128, 'RMS'), '$10^{-3}$'), 'Sigmoid') [0.27305086 0.70225447]
# (((128, 'RMS'), '$10^{-4}$'), 'ReLU') [0.79463833 0.12494677]
# (((128, 'RMS'), '$10^{-4}$'), '$tanh$') [0.84882347 0.34865021]
# (((128, 'RMS'), '$10^{-4}$'), 'Leaky\nReLU') [0.64769099 0.15374816]
# (((128, 'RMS'), '$10^{-4}$'), 'Sigmoid') [0.72334326 0.3750748 ]

# %%
# I2
I2 = nx.Graph()
I2.add_edge('[32, 64]', '[32, 64, 128]')
I2.add_edge('[32, 64, 128]', '[32, 64, \n   128, 256]')

P4 = nx.cartesian_product(P3, I2)

cmap = LinearSegmentedColormap.from_list('newCmap', ['#6495ED', '#D22B2B', '#3EB489', '#FF5F7E'])

pos = nx.spring_layout(P3)

attrs = {nodeVal:[0, 0.25, 0.75, 1.0] for nodeVal in P3.nodes()}
colors= {}

plt.figure(figsize=(12,12))
for key, val in attrs.items():
    colors[key] = list(np.array(val))
    
# positions
txtList   = []
coordList = []

for k, v in pos.items():
    print(k, v)
    txtList.append(str(k).replace("\'", ""))
    coordList.append(v)

# draw edges
nx.draw_networkx_edges(P3, pos=pos)

# color nodes
for node in P3.nodes():
    attributes = attrs[node]
    # pie
    a = plt.pie(
        [1]*len(attributes), # s.t. all wedges have equal size
        center=pos[node], 
        colors = [cmap(a) for a in colors[node]],
        radius=0.045)

plt.ylim(-1,1)
plt.xlim(-1,1)


# text formatting
newTxtList = []
for i in range(len(txtList)): 
    newT = [patt.replace('$10^{', '').replace('}$', '') if '$' in patt else patt for patt in txtList[i].replace(')', '').replace('(', '').split(', ')]
    newTxtList.append(r', '.join(newT[:-2] + [r'$10^{' + str(newT[-2]) + '}$'] + [newT[-1]]))

#for i in range(len(newTxtList)):
#    plt.text(s=newTxtList[i].replace('SGD,', 'SGD,\n').replace('Adam,', 'Adam,\n').replace('RMS,', 'RMS,\n'), 
#             x=coordList[i][0]-0.07,
#             y=coordList[i][1]-0.025, 
#             c='white', 
#             fontsize=3)

plt.show()
