# %%
import numpy as np
import matplotlib.pyplot as plt
from pygsp import graphs, filters, plotting

# %%
plotting.BACKEND = 'matplotlib'
plt.rcParams['figure.figsize'] = (10, 5)

# %%
G.set_coordinates('ring2D')
fig, ax = G.plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [21], in <cell line: 2>()
#       1 G.set_coordinates('ring2D')
# ----> 2 fig, ax = G.plot()
#
# TypeError: cannot unpack non-iterable NoneType object

# %%
G = graphs.Logo()
G.compute_fourier_basis()

fig, axes = plt.subplots(1, 2, figsize=(10, 3))
for i, ax in enumerate(axes):
    _ = G.plot(G.U[:, i+1], vertex_size=30, ax=ax)
    _ = ax.set_title('Eigenvector {}'.format(i+2))
    ax.set_axis_off()
fig.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [25], in <cell line: 5>()
#       4 fig, axes = plt.subplots(1, 2, figsize=(10, 3))
#       5 for i, ax in enumerate(axes):
# ----> 6     _ = G.plot(G.U[:, i+1], vertex_size=30, ax=ax)
#       7     _ = ax.set_title('Eigenvector {}'.format(i+2))
#       8     ax.set_axis_off()
#
# TypeError: plot() takes 1 positional argument but 2 were given
